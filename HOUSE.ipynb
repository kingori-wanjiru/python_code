# %% [markdown]
# <a href="https://colab.research.google.com/github/kingori-wanjiru/python_code/blob/main/HOUSE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#housing
import pandas as pd
wainaina = pd.read_csv('/content/Housing.csv')
print("Shape of the dataset:", wainaina.shape)
wainaina.head(20)
# Out:
# Shape of the dataset: (545, 6)
#        price   area  bedrooms  bathrooms  stories  parking
# 0   13300000   7420         4          2        3        2
# 1   12250000   8960         4          4        4        3
# 2   12250000   9960         3          2        2        2
# 3   12215000   7500         4          2        2        3
# 4   11410000   7420         4          1        2        2
# 5   10850000   7500         3          3        1        2
# 6   10150000   8580         4          3        4        2
# 7   10150000  16200         5          3        2        0
# 8    9870000   8100         4          1        2        2
# 9    9800000   5750         3          2        4        1
# 10   9800000  13200         3          1        2        2
# 11   9681000   6000         4          3        2        2
# 12   9310000   6550         4          2        2        1
# 13   9240000   3500         4          2        2        2
# ...
