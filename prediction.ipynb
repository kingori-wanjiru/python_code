# %% [markdown]
# <a href="https://colab.research.google.com/github/kingori-wanjiru/python_code/blob/main/prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
# x-axis values
x = [0, 16, 10, 27, 20, 28, 30, 39, 40, 39, 50, 60]
# y-axis values
y = [16, 27, 39, 48, 39, 48, 55, 62, 59, 67, 69, 79]
# Create a scatter plot
plt.scatter(x, y)
# Label the axes
plt.xlabel("Leaving home x minutes after 7 am")
plt.ylabel("Travel time y minutes")
# Add a title
plt.title("travel time vs. leaving time")
# Show the plot
plt.show()
#  mean and standard deviation of x and y
x_mean = np.mean(x)
y_mean = np.mean(y)
x_std = np.std(x)
y_std = np.std(y)
# Calculate the slope and intercept of the regression line
b = np.cov(x, y)[0][1] / np.var(x)
a = y_mean - b * x_mean
# Print the equation of the regression line
print("The equation is:\ny = {} + {}x".format(a, b))
# x-axis values
x = [0, 16, 10, 27, 20, 28, 30, 39, 40, 39, 50, 60]
# y-axis values
y = [16, 27, 39, 48, 39, 48, 55, 62, 59, 67, 69, 79]

# Calculate the slope and intercept of the regression line
b = np.cov(x, y)[0][1] / np.var(x)
a = y_mean - b * x_mean
# Generate x-axis values for the regression line
x_reg = np.linspace(0, 60, 100)
# Calculate y-axis values for the regression line
y_reg = a + b * x_reg
# Create a scatter plot
plt.scatter(x, y)
# Plot the regression line
plt.plot(x_reg, y_reg, color='red')
# Label the axes
plt.xlabel("Leaving home x minutes after 7 am")
plt.ylabel("Travel time y minutes")
# Add a title 2nd
plt.title(" travel time vs. leaving time with regression line")
# Show the plot
plt.show()
# Out:
# The equation is:
# y = 16.869834185857414 + 1.1296991358487771x

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

steve = pd.read_csv('/content/Housing.csv')
X = steve[["bedrooms", "bathrooms", "stories", "parking",]]
y = steve["price"]

# Split the dataset into a training set and a test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=42)

# Linear Regression model
model = LinearRegression()
model.fit(X_train, y_train)

# Create new data point with all the necessary one-hot encoded columns
newdata = pd.DataFrame({
    "bedrooms": [4],
    "bathrooms": [2],
    "stories": [3],
    "parking": [2],
})

predicted_price = model.predict(newdata)
print(f"Predicted Price: {predicted_price[0]}")
# Out:
# Predicted Price: 7070133.422582531
